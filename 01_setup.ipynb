# %% [markdown]
# ### About
# designed a medallion architecture integrating two heterogeneous data sources: a historical relational dataset and a live telemetry API. The Bronze layer preserves source fidelity, the Silver layer standardizes and integrates the data, and the Gold layer provides analytics-ready models

# %% [markdown]
# ### Create Catalog

# %%
# %sql
SHOW CATALOGS;

# %%
# %sql

CREATE CATALOG IF NOT EXISTS f1_warehouse

# %% [markdown]
# ### Create Schemas

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS f1_warehouse.bronze;
    
CREATE SCHEMA IF NOT EXISTS f1_warehouse.silver;

CREATE SCHEMA IF NOT EXISTS f1_warehouse.gold;

CREATE SCHEMA IF NOT EXISTS f1_warehouse.ingestion;

# %% [markdown]
# ### Create Volume
# * for raw files (landing zone/storage)
# * bronze table is stricly for feelata tbales (store structured analytical data you want ot query with SQL)

# %%
# %sql

CREATE VOLUME IF NOT EXISTS f1_warehouse.ingestion.raw_files;

# %%
# create seperate subfolders for incremental and historical files
dbutils.fs.mkdirs("/Volumes/f1_warehouse/ingestion/raw_files/kaggle")

dbutils.fs.mkdirs("/Volumes/f1_warehouse/ingestion/raw_files/openf1")
